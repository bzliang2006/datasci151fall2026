# %% [markdown]
# #### This is my first jupyter notebook
# ^^ personal note -> include a space after the hashes

# %%
print("My name is Benjamin" + " Liang")
#recall that python works like english 
#you can tokenize characters
# Out:
# My name is Benjamin Liang
